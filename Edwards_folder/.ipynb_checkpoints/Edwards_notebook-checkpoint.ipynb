# %% [markdown]
# Introduction
#
# Our goal is to find the best neighborhood in Pittsburgh in which to raise a family.  We determined that such a neighborhood must be safe, be close to good schools, and have a good number of family-friendly businesses.  Other metrics we decided not to include in our report (but did consider) were bus routes and traffic data.
#
# Over 50% of Americans between the ages of 18 and 40 have children (according to https://news.gallup.com/poll/164618/desire-children-norm.aspx#:~:text=More%20than%20half%20of%20Americans,not%20want%20to%20have%2C%20children.).  This is why we decided that the best neighborhood in Pittsburgh would have to be one where it is easy to raise a family.  But what factors are conducive to raising a family?  After much consideration, our group chose three: safety, schools, and businesses.  Safety is the most obvious factor, since of course you would want your family's neighborhood to be safe.  The next factor is how close a given neighborhood is to the most schools,

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

school_data = pd.read_csv("schooldata.csv")
#plot = school_data["Estimate; Total:"].plot.bar(ascending = False)
plot = school_data.sort_values(["Estimate; Total:"], ascending = False).set_index("Neighborhood")["Estimate; Total:"].head(10).plot.bar()

#school_data.head(3)
